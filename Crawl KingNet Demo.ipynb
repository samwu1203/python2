# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
import requests
driver = Chrome() # 1
driver.implicitly_wait(3)
driver.get("http://hospital.kingnet.com.tw/medicine/")
driver.find_element_by_link_text("ACETAMINOPHEN PARACETAMOL").click()
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
#driver.waitForElementPresent(locator)
soup = BeautifulSoup(driver.page_source, 'lxml')
article=soup.find_all('div')
#article=soup.find_all('div', style="height: 220px; overflow: auto;")
for list in article:
    print list.text
# Out:
# 健康新聞
# 問診紀錄
# 快問快答
# 醫護百科
# 電影音樂
# 旅遊新聞
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 國家網路醫藥
#
#
# 免費醫藥諮詢
#
#
#
#
#
#
#
# 	function loginformpup(showornot){
#
# 				if(showornot=="block"){
# 				location.href='http://member.kingnet.com.tw/loginPage.html?url='+encodeURIComponent('http://hospital.kingnet.com.tw/medicine/medicine.html?medno=us5U6s3eEy1V');
# 				}
# 	}
#
#
#
#
# 請先登入Ｘ
#
#
#
#
#
#
# 使用KingNet帳號登入
#
#
# 帳號
#
#
#
# 密碼
#
#
#
#
#
# 使用Facebook帳號登入
#   // This is called with the results from from FB.getLoginStatus().
#   function statusChangeCallback(response) {
#     console.log('statusChangeCallback');
#     console.log(response);
#     // The response object is returned with a status field that lets the
#     // app know the current login status of the person.
#     // Full docs on the response object can be found in the documentation
#     // for FB.getLoginStatus().
#     if (response.status === 'connected') {
#       // Logged into your app and Facebook.
# ...

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
import requests
driver = Chrome() # 1
driver.implicitly_wait(3)
driver.get("http://hospital.kingnet.com.tw/medicine/")
driver.find_element_by_link_text("ACETAMINOPHEN PARACETAMOL").click()
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
#driver.waitForElementPresent(locator)
soup = BeautifulSoup(driver.page_source, 'lxml')
article=soup.select('.IntroBox')
#article=soup.find_all('div', style="height: 220px; overflow: auto;")
for list in article:
    print list.text
# Out:
# 相同成份藥品名(廠商)A.A.P  (信元)A.T.  (利達)ACEDOL  (皇佳)ACETA  (正和)ACETA 200  (回春堂)ACETAL  (瑞安)ACETAMINOPHEN  (永昌、培力、安星)ACETAMINOPHEN  (北進、福元、陽生)ACETAMINOPHEN  (龍杏、元澤、華興)ACETAMINOPHEN  (優生、永吉、王子)ACETAMINOPHEN  (建康、世紀)ACETAMOL  (衛達)ACETANIN  (豐田)ACETASUPP  (回春堂)ACETASUPPO  (培力)ALCON  (明德)ANACIN-3  (東洲)ANACIN-3 FOR CHILDREN  (台灣東洋)ANLITON  (永勝)ANSTAFEN  (黃氏)APAP  (強生)APAP ELIXIR  (景德)BOCOTON  (寶齡)CHILDREN ACETA SUPP  (回春堂)CHILDREN'S LACTAM  (杏輝)CHILDRENACETA80  (回春堂)DEANTONLIQ  (羅得)DEPAIN  (華盛頓)DEPYRETIN  (榮民)FETON SUPP  (回春堂)FUCOLE PARAN  (永信)KONATON  (國嘉)LACTAM  (杏輝)MINOPHEN  (優良)NAPA  (瑞士)PACINEL  (永新)PACINOL  (永新)PANACON  (信元)PANADOL  (溫莎)PANADOL FOR CHILDREN  (溫莎)PANATOL  (明大、泠生)PARACETAMOL  ()PARACETAMOL  (華孚)PARAMOL  (生達)PARAN  (永信)PARANOL  (人人)PASTON  (維民二元)PIANT  (利國)PILINTON  (華孚)PINSU  (杏林)POROSYRUP  (永信)PYLINATON  (好漢賓)PYMADON  (井田)PYRINAZIN  (西華)PYRINAZIN  (山之內)PYRUDON  (大豐)RAMOL  (漢堡)SCANOL  (丹麥、斯肯漢)STONE  (國際)SUKAINN  (居禮)TEMPTE  (仁興)THIOTON  (明德)TINTEN  (中化)TONPHEN  (合誠)WAH-FOODE-F
# ...

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
import requests
driver = Chrome() # 1
driver.implicitly_wait(3)
driver.get("http://hospital.kingnet.com.tw/medicine/")
driver.find_element_by_link_text("ACETAMINOPHEN PARACETAMOL").click()
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
driver.implicitly_wait(3)
#driver.waitForElementPresent(locator)
soup = BeautifulSoup(driver.page_source, 'lxml')
article=soup.select("'tr class' > div")
#article=soup.find_all('div', style="height: 220px; overflow: auto;")
for list in article:
    print list.text
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-36-98e21d9f4f21> in <module>()
#      15 driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
#      16 driver.implicitly_wait(3)
# ---> 17 driver.find_element_by_xpath(u"//input[@value='顯示詳細藥物資訊']").click()
#      18 driver.implicitly_wait(3)
#      19 #driver.waitForElementPresent(locator)
#
# C:\Users\user\Anaconda2\lib\site-packages\selenium\webdriver\remote\webelement.pyc in click(self)
#      70     def click(self):
#      71         """Clicks the element."""
# ---> 72         self._execute(Command.CLICK_ELEMENT)
#      73
#      74     def submit(self):
#
# C:\Users\user\Anaconda2\lib\site-packages\selenium\webdriver\remote\webelement.pyc in _execute(self, command, params)
#     459             params = {}
#     460         params['id'] = self._id
# ...

# %%
type(article)
# Out:
# bs4.element.ResultSet

# %%
soup=
