# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
final_list=[]
driver = Chrome() # 1
driver.implicitly_wait(5)
driver.get("http://www.u-trust.com.tw/index.aspx")
driver.find_element_by_link_text(u"北市").click()
driver.implicitly_wait(5)
soup = BeautifulSoup(driver.page_source, 'lxml')
for i in range(1,32):    
    for list in soup.find_all('u'):
            print list.text 
    final_list.append(soup.find_all('u'))
    driver.find_element_by_css_selector("a.next").click()
    soup = BeautifulSoup(driver.page_source, 'lxml')
    driver.implicitly_wait(5)
    print i
# Out:
# 花博公園公寓美3房
# 世貿捷運旁住辦大廈
# 新圓山兩房亮麗美裝潢
# 民生公園稀有朝南二村大戶
# 南京捷運全新二房車位
# 南京捷運低總價三房
# 太平洋頂級商辦+車位
# 捷運採光大三房
# 和平捷運成家三房
# 綠野豪美大三房 政大明星學區住戶品質高氣派大廳
# 微風旁超值店面一樓
# 介壽景觀電梯四房
# 面公園捷運電梯二房
# 水岸第一排101景觀戶
# 喜多朗露台美套房 採光明亮通風佳管理完善住戶單純
# 新生北2房包租公最愛
# 來自翰星的享受
# 京璽獨戶私密庭院美廈
# 南京三民溫馨美3房
# 力行小家庭美寓 木新商圈~力行學區~稀有低總美寓
# 面公園邊間美寓
# 華威八方高樓景觀戶
# 景女小富婆
# 健康學區林蔭三房
# ICRT國際社區別墅 內湖五期林蔭大道
# 萬隆書香大一樓
# 建成高樓朝外兩房
# 雙仁愛邊間美寓大四房
# 國泰公寓三房
# 面公園庭院壹樓
# 士林捷運魔術絕美二房
# 採光幸福溫馨2房
# W110璞石雅緻風
# 林肯綠蔭大樓
# 南港展覽館店面
# 葫洲捷運宅3房-伴湖小築
# 阪急市府高樓典雅4房
# 吳興國小美妝2樓
# 遠雄米蘭苑
# 木新靜巷美寓 步行3分鐘木柵市場河濱公園機能佳
# 1
# 花博公園公寓美3房
# 世貿捷運旁住辦大廈
# 新圓山兩房亮麗美裝潢
# 民生公園稀有朝南二村大戶
# 南京捷運全新二房車位
# 南京捷運低總價三房
# 太平洋頂級商辦+車位
# 捷運採光大三房
# 和平捷運成家三房
# 綠野豪美大三房 政大明星學區住戶品質高氣派大廳
# 微風旁超值店面一樓
# 介壽景觀電梯四房
# 面公園捷運電梯二房
# 水岸第一排101景觀戶
# 喜多朗露台美套房 採光明亮通風佳管理完善住戶單純
# 新生北2房包租公最愛
# 來自翰星的享受
# 京璽獨戶私密庭院美廈
# 南京三民溫馨美3房
# 力行小家庭美寓 木新商圈~力行學區~稀有低總美寓
# 面公園邊間美寓
# 華威八方高樓景觀戶
# 景女小富婆
# 健康學區林蔭三房
# ICRT國際社區別墅 內湖五期林蔭大道
# 萬隆書香大一樓
# 建成高樓朝外兩房
# 雙仁愛邊間美寓大四房
# 國泰公寓三房
# 面公園庭院壹樓
# 士林捷運魔術絕美二房
# 採光幸福溫馨2房
# W110璞石雅緻風
# 林肯綠蔭大樓
# 南港展覽館店面
# ...

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
final_list=[]
driver = Chrome() # 1
driver.implicitly_wait(5)
driver.get("http://www.u-trust.com.tw/index.aspx")
driver.find_element_by_link_text(u"北市").click()
driver.implicitly_wait(5)
soup = BeautifulSoup(driver.page_source, 'lxml')
i=1
while len(soup.select('a.next')) > 0:
    for list in soup.find_all('u'):
            print list.text 
    final_list.append(soup.find_all('u'))
    driver.find_element_by_css_selector("a.next").click()
    soup = BeautifulSoup(driver.page_source, 'lxml')
    i=i+1
    print i
    driver.implicitly_wait(5)
# Out:
# 國際有約精緻裝潢2房
# 民生社區圓環黃金三樓
# 高第12樓
# 新世界經典1+1
# 三興高投報收租屋
# 低總價邊間四房
# 建國正馬路小金雞建國花市大安森林公園
# 林森北住辦美廈
# 附中A+臻藏大戶近大安捷運站生活機能好稀有大戶
# 稀有金鑽邊間景觀兩房
# W110璞石美麗境界
# 大安謙華景觀邸
# 雙敦學區精裝附車位
# 瑞安榮華獨戶高樓
# 信義商圈3套收租屋
# 綠野豪美大三房 政大明星學區住戶品質高氣派大廳
# 內湖五期琉森花園館
# 靜心集超值2房 萬芳醫院北市捷運中國科技大學商圈
# 忠孝敦化捷運2房
# 松青超市大空間美寓
# 美秀館高樓河景
# 社子面河景美寓
# 松仁亮麗四房車位
# 榮星行天宮金店面
# 附小龍門庭院一樓
# 二村邊間林蔭美寓
# 遠雄大都市新天地
# 摩登尊爵商辦
# 松山車站低總美寓
# 阪急市府高樓典雅4房
# 松城面中庭美三房
# 介壽學區獨棟邊間美寓
# 忠孝復興三普高樓3房
# 捷運採光大三房
# 南京復興摩登美居
# 彰銀住辦一樓part1
# 三民低總黃金2樓
# 國泰公寓三房
# 麗湖學區花園四房 B39
# 五期奧斯卡加車位
# 2
# 國際有約精緻裝潢2房
# 民生社區圓環黃金三樓
# 高第12樓
# 新世界經典1+1
# 三興高投報收租屋
# 低總價邊間四房
# 建國正馬路小金雞建國花市大安森林公園
# 林森北住辦美廈
# 附中A+臻藏大戶近大安捷運站生活機能好稀有大戶
# 稀有金鑽邊間景觀兩房
# W110璞石美麗境界
# 大安謙華景觀邸
# 雙敦學區精裝附車位
# 瑞安榮華獨戶高樓
# 信義商圈3套收租屋
# 綠野豪美大三房 政大明星學區住戶品質高氣派大廳
# 內湖五期琉森花園館
# 靜心集超值2房 萬芳醫院北市捷運中國科技大學商圈
# 忠孝敦化捷運2房
# 松青超市大空間美寓
# 美秀館高樓河景
# 社子面河景美寓
# 松仁亮麗四房車位
# 榮星行天宮金店面
# 附小龍門庭院一樓
# 二村邊間林蔭美寓
# 遠雄大都市新天地
# 摩登尊爵商辦
# 松山車站低總美寓
# 阪急市府高樓典雅4房
# 松城面中庭美三房
# 介壽學區獨棟邊間美寓
# 忠孝復興三普高樓3房
# 捷運採光大三房
# 南京復興摩登美居
# 彰銀住辦一樓part1
# 三民低總黃金2樓
# 國泰公寓三房
# ...
