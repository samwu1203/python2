# %% [markdown]
# # 將chromedriver 存入Path (C:\Users\user\Anaconda2\Library\bin)

# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
driver = Chrome() # 1
driver.implicitly_wait(3)
driver.get("https://tw.eztable.com/channel/200")
for i in range(1,11):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    time.sleep(1)
soup = BeautifulSoup(driver.page_source, 'lxml')
for block in soup.select('.title'):
    print block.text
# Out:
# 吃心絕對約會去
# 頤宮中餐廳 Le Palais - 君品酒店
# 瑪可緹 Mocktail tea
# 乃渥爾料理
# 夏慕尼(台北南昌店)
# 新都里 懷石料理
# 王品牛排 (台北和平東店)
# 中山日本料理廳 - 台北老爺大酒店
# 夏慕尼(台北中山北店)
# ACHOI 餐廳 - amba TAIPEI ZHONSHAN 台北中山意舍
# FIFI茶酒沙龍-常玉廳
# FIFI茶酒沙龍-W Lounge Bar
# 三花日式料理
# 大安9號鍋物。日本料理
# L'IDIOT RESTAURANT 驢子餐廳
# 丹耶澧義大利餐廳-The Westin Taipei 台北威斯汀六福皇宮
# Elite Café - The Westin Taipei 台北威斯汀六福皇宮
# 祇園日本料理-The Westin Taipei 台北威斯汀六福皇宮
# 留園上海料理-The Westin Taipei 台北威斯汀六福皇宮
# Churchill 邱吉爾爵士雪茄館-The Westin Taipei  台北威斯汀六福皇宮
# Danny’s WhatsNabe
# 三角三韓國道地烤肉 (西門店)
# Cozzi KITCHEN-和逸飯店 (台北民生館)
# Closet Restaurant & Bar
# 台北怡亨酒店 Eclat Lounge
# Alexander's Steakhouse Taipei 亞歷山大牛排台北店
# Senn 先酒肴
# WINE-derful葡萄酒主題餐廳
# Bianco Taipei 義大利食材餐廳
# SONOMA Global Steak House-焱牛排館
# Coffee Please By Mastro
# 愛新覺羅 原味‧鮮採嚴煮
# Bon Amis Steak Room-神旺大飯店
# W XYZ 酒吧
# 雅室牛排館 Steak Inn
# Skaka
# 燈燈庵日式料理餐廳
# MVSA Spanish Restaurant & Bar 沐紗西班牙酒莊餐廳
# 犇 和牛館 私人會所
# RUBY CAFE
# Homie Cafe
# 遇東方精緻料理餐廳
# 和羹 WAKO 創意日本料理
# SONOMA Grill Steak & Teppanyaki-帝國牛排館
# 知貳茶館
# Osteria by angie (光復店)
# Moi cafe
# 地中海牛排館-歐華酒店
# 星辰牛排
# 囍聚精緻鍋物
# 圓桌鐵板燒涮涮鍋 (鐵板燒區)
# 圓桌鐵板燒涮涮鍋 (涮涮鍋區)
# 王品牛排 (台北光復南店)
# Oyster Bar by Fujin tree 富錦樹生蠔吧
# 王品牛排 (台北南京東店)
# 夏慕尼 (台北光復北店)
# Monsieur L Restaurant - L先生義法餐廳
# In Between 之間牛排館  誠品行旅
# 寶艾西餐廳-台北君悅酒店 Grand Hyatt Taipei
# 漂亮廣式海鮮餐廳-台北君悅酒店 Grand Hyatt Taipei
# Cheers-台北君悅酒店 Grand Hyatt Taipei
# 雲錦中餐廳-台北君悅酒店 Grand Hyatt Taipei
# DA ANTONIO By 隨意鳥地方
# MW 時尚義法料理&酒品(八德店)
# 隨意吧Sui Business Lounge  By 隨意鳥地方
# French Windows 琺蘭綺瑥朵茶餐館 (台北店)
# 犇 (微風信義館)
# Osteria by Angie (信義微風店)
# Office By Mastro
# 燄 Move Deluxe
# Lawry's 勞瑞斯牛肋排餐廳
# Joyce East義法創意料理
# Taverna De ' Medici 梅帝騎小酒館
# 夏慕尼(中和中山店)
# Black Bull Farm 黑牛牧場
# MW 時尚義法料理&酒品(大直店)
# Danny & Company Bistro (大直店)
# Osteria by Angie (大直店)
# 瑞德餐廳 La Riche Cellier - 台北大直店
# 夏慕尼(台北內湖店)
# 2011 精緻鐵板料理 美食.醇酒.音樂
# Diamond Tony's Bistro 隨意鳥地方義大利菜（大直店）
# 夏慕尼(板橋民生店)
# Mastro Cafe
# 婧SHABU
# 三角三韓國道地烤肉 (板橋店)
# 非煮不可精緻鍋物
# 品川精緻鍋物
# 王品牛排 (板橋縣民大道店)
# JAMEI CHEN 另空間 X OSTERIA BY ANGIE
# The Lounge 大廳酒吧-台北六福萬怡酒店
# Isaac Eatalian Cuisine 義薩格義式料理
# 納美花園
# 少帥禪園
# 風雅湯屋 - 天籟渡假酒店
# 夏慕尼(桃園中山東店)
# 王品牛排 (桃園同德店)
# 王品牛排 (中壢延平店)
# 夏慕尼(中壢延平店)
# 夏慕尼(竹北光明店)
# 波咔 Pokaa Cafe & Bistro
# 中山日本料理-新竹老爺酒店
# 老爺鐵板燒-新竹老爺酒店
# 米蘭精緻鐵板燒
# 王品牛排 (新竹北大店)
# 夏慕尼(台中文心店)
# 王品牛排 (台中文心店)
# 王品牛排 (台中五權店)
# 冠品鐵板燒-長榮桂冠酒店(台中)
# 長園中餐廳-長榮桂冠酒店(台中)
# Beluga restaurant & bar
# 夏慕尼(台中大隆店)
# 印月創意東方宴
# 真月新日本料理
# 法月當代法式料理
# 樂軒日式鍋物料亭
# 樂軒究極和牛燒肉
# Isabati 義薩芭蒂義式料理
# 王品牛排 (台南中華東店)
# 轉角餐廳 Corner Steak House
# 夏慕尼(台南公園南店)
# Cozzi KITCHEN-和逸飯店 (台南西門館)
# 月見溪創意餐廳
# 夏慕尼(台南永華店)
# 牛排屋鐵板燒 The Cut - 義大皇家酒店
# 義大利餐廳- 義大皇家酒店
# 帕莎蒂娜法式餐廳
# 王品牛排 (高雄明誠店)
# SKY觀景西餐
# Boston 波士頓龍蝦餐廳
# 王品牛排 (高雄中正店)
# 夏慕尼(高雄五福店)
# 安多尼歐法式餐廳
# The Roof-和逸飯店 (高雄中山館)
# Le Petit-和逸飯店 (高雄中山館)
# Le Bar 吧 戶外餐廳 - 君品酒店
# 花園日本料理 - 台北花園大酒店
# 欣葉咖哩匠-中山店
# 玫瑰夫人餐廳-旗艦店
# 九華樓 - 華泰王子大飯店
# Danny & Company

# %%
dir(driver)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_file_detector',
#  '_is_remote',
#  '_mobile',
#  '_switch_to',
#  '_unwrap_value',
#  '_wrap_value',
#  'add_cookie',
#  'application_cache',
#  'back',
#  'capabilities',
#  'close',
#  'command_executor',
#  'create_options',
#  'create_web_element',
#  'current_url',
#  'current_window_handle',
#  'delete_all_cookies',
#  'delete_cookie',
#  'desired_capabilities',
#  'error_handler',
#  'execute',
#  'execute_async_script',
#  'execute_script',
#  'file_detector',
#  'file_detector_context',
#  'find_element',
#  'find_element_by_class_name',
#  'find_element_by_css_selector',
#  'find_element_by_id',
#  'find_element_by_link_text',
#  'find_element_by_name',
#  'find_element_by_partial_link_text',
#  'find_element_by_tag_name',
#  'find_element_by_xpath',
#  'find_elements',
#  'find_elements_by_class_name',
#  'find_elements_by_css_selector',
#  'find_elements_by_id',
#  'find_elements_by_link_text',
#  'find_elements_by_name',
#  'find_elements_by_partial_link_text',
#  'find_elements_by_tag_name',
#  'find_elements_by_xpath',
#  'forward',
#  'get',
#  'get_cookie',
#  'get_cookies',
#  'get_log',
#  'get_screenshot_as_base64',
#  'get_screenshot_as_file',
#  'get_screenshot_as_png',
#  'get_window_position',
#  'get_window_size',
#  'implicitly_wait',
#  'launch_app',
#  'log_types',
#  'maximize_window',
#  'mobile',
#  'name',
#  'orientation',
#  'page_source',
#  'quit',
#  'refresh',
#  'save_screenshot',
#  'service',
#  'session_id',
#  'set_page_load_timeout',
#  'set_script_timeout',
#  'set_window_position',
#  'set_window_size',
#  'start_client',
#  'start_session',
#  'stop_client',
#  'switch_to',
#  'switch_to_active_element',
#  'switch_to_alert',
#  'switch_to_default_content',
#  'switch_to_frame',
#  'switch_to_window',
#  'title',
#  'w3c',
#  'window_handles']
