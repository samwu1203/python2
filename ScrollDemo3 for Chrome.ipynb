# %%
from selenium.webdriver import Chrome
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
from bs4 import BeautifulSoup
driver = Chrome() # 1
driver.implicitly_wait(3)
driver.get("https://tw.eztable.com/channel/200")
art_list = []
art_dict = {}
final_list = []
for i in range(1,11):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    time.sleep(1)
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
title_list = soup.find_all('div', class_='title')
city_list = soup.find_all('span', class_='ftag city')
curisine_list = soup.find_all('span', class_='ftag cuisine')
len(title_list)
# Out:
# 188

# %%
len(city_list)
# Out:
# 188

# %%
len(curisine_list)
# Out:
# 188

# %%
print title_list[0].text
# Out:
# 頤宮中餐廳 Le Palais - 君品酒店

# %%
print city_list[0].text
# Out:
# 台北市

# %%
print curisine_list[0].text
# Out:
# 亞洲料理

# %%
art_dict = {}
final_list = []
for i in range(0,188):
    art_dict = {'title':title_list[i].text,'city':city_list[i].text,'curisine':curisine_list[i].text},
    final_list.append(art_dict),

# %%
final_list[100]['curisine']
# Out:
# u'\u4e9e\u6d32\u6599\u7406'

# %%
final_list
# Out:
# [{'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u4e9e\u6d32\u6599\u7406',
#   'title': u'\u9824\u5bae\u4e2d\u9910\u5ef3 Le Palais - \u541b\u54c1\u9152\u5e97'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u897f\u5f0f\u6599\u7406',
#   'title': u'\u746a\u53ef\u7df9 Mocktail tea'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u82b1\u65d7\u9996\u9078\u5e2d\u4f4d',
#   'title': u'\u4e43\u6e25\u723e\u6599\u7406'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u897f\u5f0f\u6599\u7406',
#   'title': u'\u590f\u6155\u5c3c(\u53f0\u5317\u5357\u660c\u5e97)'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u4e9e\u6d32\u6599\u7406',
#   'title': u'\u65b0\u90fd\u91cc \u61f7\u77f3\u6599\u7406'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u897f\u5f0f\u6599\u7406',
#   'title': u'\u738b\u54c1\u725b\u6392 (\u53f0\u5317\u548c\u5e73\u6771\u5e97)'},
#  {'city': u'\u53f0\u5317\u5e02',
#   'curisine': u'\u4e9e\u6d32\u6599\u7406',
# ...

# %%
import pandas as pd

# %%
article = pd.DataFrame(final_list)

# %%
article
# Out:
#     city curisine                                            title
# 0    台北市     亞洲料理                           頤宮中餐廳 Le Palais - 君品酒店
# 1    台北市     西式料理                                 瑪可緹 Mocktail tea
# 2    台北市   花旗首選席位                                            乃渥爾料理
# 3    台北市     西式料理                                       夏慕尼(台北南昌店)
# 4    台北市     亞洲料理                                         新都里 懷石料理
# 5    台北市     西式料理                                    王品牛排 (台北和平東店)
# 6    台北市     亞洲料理                                中山日本料理廳 - 台北老爺大酒店
# 7    台北市     西式料理                                      夏慕尼(台北中山北店)
# 8    台北市     西式料理           ACHOI 餐廳 - amba TAIPEI ZHONSHAN 台北中山意舍
# 9    台北市     多國料理                                     FIFI茶酒沙龍-常玉廳
# 10   台北市     多國料理                            FIFI茶酒沙龍-W Lounge Bar
# 11   台北市     亞洲料理                                           三花日式料理
# 12   台北市     亞洲料理                                      大安9號鍋物。日本料理
# ...

# %%
import MySQLdb

# %%
db = MySQLdb.connect("localhost", "root", "1234", "pyrhondb")

# %%
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
engine = sqlalchemy.create_engine('mysql+mysqldb://root:1234@localhost/pyrhondb?charset=utf8')

# %%
article.count()
# Out:
# city        188
# curisine    188
# title       188
# dtype: int64

# %%
article.describe()
# Out:
#        city curisine         title
# count   188      188           188
# unique    9       10           188
# top     台北市     西式料理  愛新覺羅 原味‧鮮採嚴煮
# freq    115       97             1

# %%
article_stat = article.groupby('city').count().sort_values('title', ascending=False)

# %%
article_stat
# Out:
#       curisine  title
# city
# 台北市        115    115
# 台中市         17     17
# 新北市         15     15
# 高雄市         14     14
# 台南市         11     11
# 新竹市          6      6
# 桃園市          5      5
# 新竹縣          3      3
# 南投縣          2      2

# %%
print article_stat.index
# Out:
# Index([u'台北市', u'台中市', u'新北市', u'高雄市', u'台南市', u'新竹市', u'桃園市', u'新竹縣', u'南投縣'], dtype='object', name=u'city')

# %%
article_stat.to_sql('Ez_table', engine, if_exists='replace', index=False, index_label=article_stat.index)

# %%
article.to_sql('Ez_table2', engine, if_exists='replace', index=False, index_label=article.index)
# Out:
# C:\Users\user\Anaconda2\lib\site-packages\pandas\io\sql.py:1267: UserWarning: The provided table name 'Ez_table2' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
